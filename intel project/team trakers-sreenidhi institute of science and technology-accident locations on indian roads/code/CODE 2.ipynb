# %%
# Import the required Module
#to import pdf file for the Andhra_Pradesh state from 
import tabula
# Read a PDF File
df = tabula.read_pdf("https://morth.nic.in/sites/default/files/Andhra_Pradesh.pdf", pages='all')[0]
# convert PDF into CSV
tabula.convert_into("https://morth.nic.in/sites/default/files/Andhra_Pradesh.pdf", "black_spots.csv", output_format="csv", pages='all')
print(df)
# Out:
#    25 Black Spots in the State of Andhra Pradesh             Unnamed: 0
# 0                                        S.\rNo.  Name of the\rDistrict  \
# 1                                              1             Srikakulam
# 2                                              2          West Godavari
# 3                                              3                     do
# 4                                              4                     do
# 5                                              5                Nellore
# 6                                              6                Kurnool
# 7                                              7                     do
# 8                                              8                     do
# 9                                              9             Karimnagar
# 10                                            10                  Medak
# 11                                            11                  Medak
# 12                                            12                  Medak
# 13                                            13              Nizamabad
# 14                                            14                     do
# 15                                            15                     do
# 16                                            16                Adilbad
# 17                                            17              Cyberabad
# 18                                            18                     do
# 19                                            19                     do
# 20                                            20                     do
# 21                                            21                     do
# 22                                            22           Mahabubnagar
# 23                                            23                     do
# 24                                            24               Nalgonda
# 25                                            25                     do
#
#                       Unnamed: 1
# 0   Juridiction/\rPolice Station  \
# 1                       Etcheria
# 2                   Tanuku Rural
# 3                    Eluru Rural
# 4                       Chebrolu
# 5                        Kaavali
# 6                         Papili
# 7                        Orvakal
# 8                          Dhone
# 9                        Koratla
# 10              Zaheerabad\rTown
# 11                 Zaheerabad To
# 12             Sangareddy\rRural
# 13                 Sadasiva Naga
# 14                     Balakonda
# 15                        Aarmur
# 16                        Jaipur
# 17                 Rajendra Naga
# 18                 Chaitanyapuri
# 19                         Uppal
# 20                       Medchal
# 21                       Miyapur
# 22                        Kothur
# 23                    Kodandapur
# 24                    Chouluppal
# 25                            do
#
#                                            Unnamed: 2 Unnamed: 3
# 0   Location of accidents including\rchainage (km ...    NH\rNo.  \
# 1                                Navabharath Junction         16
# 2                                 Tetali 'Y' Junction         16
# 3                                      ASRAM Hospital         16
# 4                                     Kaikaram Center         16
# 5                                          Maddurpadu         16
# 6                                  Enugumarri Village         44
# 7                                     Pudicherlametta         40
# 8   Bharath Petrol Bunk, Near\rUngaraanikunta Village         44
# 9                       Arora Junior College, Koratla         63
# 10                                Palpanooru 'X' Road         65
# 11                            Near RTA Checkpost area         65
# 12                                   Pothireddy Palli         65
# 13                     Adluru Yellareddy 'T' Junction         44
# 14                                 Balakonda Junction         44
# 15                                   Perkiti 'X' Road         63
# 16                                            Indaram         63
# 17                                        Gangagpahad         44
# 18                                 Kothapeta 'X' Road         65
# 19                                     Uppal 'X' Road        163
# 20                                            Medchal         44
# 21                                            Miyapur         65
# 22                                  Thimmapur Village         44
# 23                                       Vemula Stage         44
# 24                    Veliminada Bridge, Near Hanuman         65
# 25                             Pedakaparthy Bus Stage         65
#
#                             Unnamed: 4                       Unnamed: 5
# 0   No of\rfatalities\r(2008 to\r2010)  Reasons for frequent\raccidents
# 1                                   12                              NaN
# 2                                   22                              NaN
# 3                                   19                              NaN
# 4                                   16                              NaN
# 5                                   40                              NaN
# 6                                   25                              NaN
# 7                                   23                              NaN
# 8                                   34                              NaN
# 9                                   36                              NaN
# 10                                  29                              NaN
# 11                                  23                              NaN
# 12                                  14                              NaN
# 13                                  14                              NaN
# 14                                  44                              NaN
# 15                                  18                              NaN
# 16                                  18                              NaN
# 17                                  17                              NaN
# 18                                  28                              NaN
# 19                                  44                              NaN
# 20                                  54                              NaN
# 21                                  23                              NaN
# 22                                  18                              NaN
# 23                                  32                              NaN
# 24                                  34                              NaN
# 25                                  28                              NaN

# %%
import csv
  
# Open file
#csv.writer("black_spots_data.csv", dialect='excel', **fmtparams)

file_out = "black_spots_data.csv"
with open (file_out,'w',newline='') as csvfile:
    csvwriter = csv.writer(csvfile)
    with open('black_spots.csv') as file_obj:
      
           heading = next(file_obj)
   
    # Create reader object by passing the file 
    # object to reader method
           reader_obj = csv.reader(file_obj)
      
    # Iterate over each row in the csv file 
    # using reader object
           for row in reader_obj:
               if row[1] == 'do':
                  row[1] = prev_dist
               prev_dist = row[1]
               if row[2] == 'do':
                  row[2] = prev_juridiction  
               prev_juridiction = row[2]
               csvwriter.writerow(row)
             #  print(row)

# %%
from geopy.geocoders import Nominatim
 
# calling the Nominatim tool
loc = Nominatim(user_agent="GetLoc")
 
# entering the location name
#getLoc = loc.geocode("AndhraPradesh Srikakulam")
#Text1 = "Srikakulam"
getLoc = loc.geocode("Cyberabad")
#getLoc = loc.geocode(Text1)
 
# printing address
print(getLoc.address)
 
# printing latitude and longitude
print("Latitude = ", getLoc.latitude, "\n")
print("Longitude = ", getLoc.longitude)
# Out:
# HITEC City, Ward 107 Madhapur, Serilingampalle mandal, Hyderabad, Rangareddy, Telangana, 500081, India
# Latitude =  17.4508058
#
# Longitude =  78.3834535

# %%
import csv
from geopy.geocoders import Nominatim


# calling the Nominatim tool
loc = Nominatim(user_agent="GetLoc")

# Open file
#csv.writer("black_spots_data.csv", dialect='excel', **fmtparams)

file_out = "black_spots_data.csv"
with open (file_out,'w',newline='') as csvfile:
    csvwriter = csv.writer(csvfile)
    with open('black_spots.csv') as file_obj:
      
         #  heading = next(file_obj)
   
    # Create reader object by passing the file 
    # object to reader method
           reader_obj = csv.reader(file_obj)
      
    # Iterate over each row in the csv file 
    # using reader object
           for row in reader_obj:
               if row[1] == 'do':
                  row[1] = prev_dist
               prev_dist = row[1]
               if row[2] == 'do':
                  row[2] = prev_juridiction  
               prev_juridiction = row[2]
             
               if row == 1: break
               if row[2] == " ": break
               print ("column 2 :",row[2])
              # location_text = row[1]+" "+row[2]
               location_text = row[1].rjust(10)
                
               print ("Location",location_text)
               print (Error_msg)
            
               getLocation = loc.geocode(location_text) 
               get_latitude = getLocation.latitude
               get_longitude = getLocation.longitude
               print("Latitude = ", get_latitude,"\n")
               print("Longitude = ", get_longitude)
               if ValueError: 
                   print ("NBTEST")
                   Error_msg1 = 1
                                     
               if Error_msg1 != 1:   
                     print ("*******")
                     Error_msg1 = 0
                     get_latitude = getLocation.latitude
                     get_longitude = getLocation.longitude
                     print("Latitude = ", get_latitude,"\n")
                     print("Longitude = ", get_longitude)
                     csvwriter.writerow(row)
               Error_msg1 = 0
                # printing address
              # print(getLoc.address)
 
# printing latitude and longitude
                    
               #csvwriter.writerow(row)
             #  print(row)
# Out:
# column 2 : Tanuku Rural
# Location West Godavari
# 1
# Latitude =  16.63713765
#
# Longitude =  81.58909665667748
# NBTEST
# column 2 : Eluru Rural
# Location West Godavari
# 1
# Latitude =  16.63713765
#
# Longitude =  81.58909665667748
# NBTEST
# column 2 : Chebrolu
# Location West Godavari
# 1
# Latitude =  16.63713765
#
# Longitude =  81.58909665667748
# NBTEST
# column 2 : Kaavali
# Location    Nellore
# 1
# Latitude =  14.4493717
#
# Longitude =  79.9873763
# NBTEST
# column 2 : Papili
# Location    Kurnool
# 1
# Latitude =  15.8309251
#
# Longitude =  78.0425373
# NBTEST
# column 2 : Orvakal
# Location    Kurnool
# 1
# Latitude =  15.8309251
#
# Longitude =  78.0425373
# NBTEST
# column 2 : Dhone
# Location    Kurnool
# 1
# Latitude =  15.8309251
#
# Longitude =  78.0425373
# NBTEST
# column 2 : Koratla
# Location Karimnagar
# 1
# Latitude =  18.4348122
#
# Longitude =  79.1328042
# NBTEST
# column 2 : Zaheerabad
# Town
# Location      Medak
# 1
# Latitude =  17.9375095
#
# Longitude =  78.21174498510584
# NBTEST
# column 2 : Zaheerabad To
# Location      Medak
# 1
# Latitude =  17.9375095
#
# Longitude =  78.21174498510584
# NBTEST
# column 2 : Sangareddy
# Rural
# Location      Medak
# 1
# Latitude =  17.9375095
#
# Longitude =  78.21174498510584
# NBTEST
# column 2 : Sadasiva Naga
# Location  Nizamabad
# 1
# Latitude =  26.055317950000003
#
# Longitude =  82.99313867937335
# NBTEST
# column 2 : Balakonda
# Location  Nizamabad
# 1
# Latitude =  26.055317950000003
#
# Longitude =  82.99313867937335
# NBTEST
# column 2 : Aarmur
# Location  Nizamabad
# 1
# Latitude =  26.055317950000003
#
# Longitude =  82.99313867937335
# NBTEST
# column 2 : Jaipur
# Location   Adilabad
# 1
# Latitude =  19.5
#
# Longitude =  78.5
# NBTEST
# column 2 : Rajendra Naga
# Location  Cyberabad
# 1
# Latitude =  17.4508058
#
# Longitude =  78.3834535
# NBTEST
# column 2 : Chaitanyapuri
# Location  Cyberabad
# 1
# Latitude =  17.4508058
#
# Longitude =  78.3834535
# NBTEST
# column 2 : Uppal
# Location  Cyberabad
# 1
# Latitude =  17.4508058
#
# Longitude =  78.3834535
# NBTEST
# column 2 : Medchal
# Location  Cyberabad
# 1
# Latitude =  17.4508058
#
# Longitude =  78.3834535
# NBTEST
# column 2 : Miyapur
# Location  Cyberabad
# 1
# Latitude =  17.4508058
#
# Longitude =  78.3834535
# NBTEST
# column 2 : Kothur
# Location Mahabubnagar
# 1
# Latitude =  16.696568550000002
#
# Longitude =  77.95911462089693
# NBTEST
# column 2 : Kodandapur
# Location Mahabubnagar
# 1
# Latitude =  16.696568550000002
#
# Longitude =  77.95911462089693
# NBTEST
# column 2 : Chouluppal
# Location   Nalgonda
# 1
# Latitude =  16.8579636
#
# Longitude =  79.21749353315548
# NBTEST
# column 2 : Chouluppal
# Location   Nalgonda
# 1
# Latitude =  16.8579636
#
# Longitude =  79.21749353315548
# NBTEST
